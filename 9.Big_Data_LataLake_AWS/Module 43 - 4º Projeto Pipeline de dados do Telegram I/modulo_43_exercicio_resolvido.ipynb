# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# ![Bot2-ativo.PNG](data:image/png;base64,...)

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# ![Bot3-Grupo criado.PNG](data:image/png;base64,...)

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# ![Bot4-add admin.PNG](data:image/png;base64,...)

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# ![Bot5-desabilitado.PNG](data:image/png;base64,...)

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# As mensagens captadas por um bot podem ser acessadas via API. A única informação
# necessária é o token de acesso fornecido pelo BotFather na criação do bot.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %%
from getpass import getpass
token = getpass()
# Out:
# ··········

# %% [markdown]
# A url base é comum a todos os métodos da API.

# %%
import json
import requests
base_url = f'https://api.telegram.org/bot{token}'

# %% [markdown]
# *   **getMe**
#
# O método getMe retorna informações sobre o bot.

# %%
response = requests.get(url=f'{base_url}/getMe')
print(f'{base_url}/getMe')
print(json.dumps(json.loads(response.text), indent=2))
# Out:
# https://api.telegram.org/bot6071882767:AAFYLIU-LVmMph27cVfUKMapnlnUqPQFbHQ/getMe
# {
#   "ok": true,
#   "result": {
#     "id": 6071882767,
#     "is_bot": true,
#     "first_name": "ebac43_nildo_bot",
#     "username": "ebac43_nildo_bot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false
#   }
# }

# %% [markdown]
# > **Nas informações acima, o getMe retornou as informações:**
#
# * **id:** 6071882767 (que é o ID único do meu Bot)
# * **is_bot:** true (sim é verdade, é um bot)
# * **first_name:** ebac43_nildo_bot (primeiro_nome)
# * **username:** ebac43_nildo_bot (nome de usuário)
# * **can_join_groups:** false (não pode entrar em grupos)
#
# Utilizei o getMe para confirmar se o token que usei estava usando realmente o Bot.

# %% [markdown]
# *  **getUpdates**
#
# O método getMe retorna as mensagens captadas pelo bot.

# %%
response = requests.get(url=f'{base_url}/getUpdates')
print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 801658181,
#       "message": {
#         "message_id": 8,
#         "from": {
#           "id": 5397026526,
#           "is_bot": false,
#           "first_name": "Nildo",
#           "last_name": "Muniz",
#           "username": "nildomuniz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -821878623,
#           "title": "Nildo, ebac43_nildo_bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1681676659,
#         "text": "Ol\u00e1 mundo! \n\ud83d\ude03"
#       }
#     },
#     {
#       "update_id": 801658182,
#       "message": {
#         "message_id": 9,
#         "from": {
#           "id": 5397026526,
#           "is_bot": false,
#           "first_name": "Nildo",
#           "last_name": "Muniz",
#           "username": "nildomuniz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -821878623,
#           "title": "Nildo, ebac43_nildo_bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1681676686,
#         "text": "\ud83d\udc68\u200d\ud83e\uddb3 grupo criado para o m\u00f3dulo 43 da ebac"
#       }
#     },
#     {
#       "update_id": 801658183,
#       "message": {
#         "message_id": 10,
#         "from": {
#           "id": 5397026526,
#           "is_bot": false,
#           "first_name": "Nildo",
#           "last_name": "Muniz",
#           "username": "nildomuniz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -821878623,
#           "title": "Nildo, ebac43_nildo_bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1681676695,
#         "text": "N\u00e3o vejo a hora de terminar o curso kkkk"
#       }
#     },
#     {
#       "update_id": 801658184,
#       "message": {
#         "message_id": 11,
#         "from": {
#           "id": 5397026526,
#           "is_bot": false,
#           "first_name": "Nildo",
#           "last_name": "Muniz",
#           "username": "nildomuniz",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -821878623,
#           "title": "Nildo, ebac43_nildo_bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1681676705,
#         "text": "Falta s\u00f3 01 m\u00f3dulo uhuuuu"
#       }
#     }
#   ]
# }
